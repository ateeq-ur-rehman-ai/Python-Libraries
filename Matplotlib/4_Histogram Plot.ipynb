# %% [markdown]
# # Histogram Plot

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
import random

a=np.random.randint(20,100,(60))
print(a)
# Out:
# [86 36 40 67 21 69 23 81 31 68 92 89 86 78 70 38 72 78 46 52 26 74 99 64
#  90 23 86 71 93 87 35 50 93 69 76 26 30 87 62 51 37 36 98 90 22 89 28 38
#  85 76 85 52 28 44 56 94 95 43 91 93]

# %%
x=[86, 36, 40, 67, 21, 69, 23, 81, 31, 68, 92, 89, 86, 78, 70, 38, 72, 78, 46,
52, 26, 74, 99, 64, 90, 23, 86, 71, 93, 87, 35, 50, 93, 69, 76, 26, 30, 87,
62, 51, 37, 36, 98, 90, 22, 89, 28, 38, 85, 76, 85, 52, 28, 44, 56, 94, 95, 43, 91, 93]

plt.hist(x)
plt.show()

# %%
x=[86, 36, 40, 67, 21, 69, 23, 81, 31, 68, 92, 89, 86, 78, 70, 38, 72, 78, 46,
52, 26, 74, 99, 64, 90, 23, 86, 71, 93, 87, 35, 50, 93, 69, 76, 26, 30, 87,
62, 51, 37, 36, 98, 90, 22, 89, 28, 38, 85, 76, 85, 52, 28, 44, 56, 94, 95, 43, 91, 93]

plt.hist(x)
plt.title("Histogram")
plt.xlabel("No Of Sales")
plt.ylabel("Years")
plt.show()

# %%
x=[86, 36, 40, 67, 21, 69, 23, 81, 31, 68, 92, 89, 86, 78, 70, 38, 72, 78, 46,
52, 26, 74, 99, 64, 90, 23, 86, 71, 93, 87, 35, 50, 93, 69, 76, 26, 30, 87,
62, 51, 37, 36, 98, 90, 22, 89, 28, 38, 85, 76, 85, 52, 28, 44, 56, 94, 95, 43, 91, 93]
l=[30,40,50,60,70,80,90]
plt.hist(x,color='m',bins=l,edgecolor='y',linewidth=3)
plt.title("Histogram")
plt.xlabel("No Of Sales")
plt.ylabel("Years")
plt.show()

# %%
x=[86, 36, 40, 67, 21, 69, 23, 81, 31, 68, 92, 89, 86, 78, 70, 38, 72, 78, 46,
52, 26, 74, 99, 64, 90, 23, 86, 71, 93, 87, 35, 50, 93, 69, 76, 26, 30, 87,
62, 51, 37, 36, 98, 90, 22, 89, 28, 38, 85, 76, 85, 52, 28, 44, 56, 94, 95, 43, 91, 93]
l=[30,40,50,60,70,80,90]
plt.hist(x,color='m',bins=l,edgecolor='y',linewidth=3,cumulative=-1)
plt.title("Histogram")
plt.xlabel("No Of Sales")
plt.ylabel("Years")
plt.show()

# %%
x=[86, 36, 40, 67, 21, 69, 23, 81, 31, 68, 92, 89, 86, 78, 70, 38, 72, 78, 46,
52, 26, 74, 99, 64, 90, 23, 86, 71, 93, 87, 35, 50, 93, 69, 76, 26, 30, 87,
62, 51, 37, 36, 98, 90, 22, 89, 28, 38, 85, 76, 85, 52, 28, 44, 56, 94, 95, 43, 91, 93]
l=[30,40,50,60,70,80,90]
plt.hist(x,"auto",(30,200),edgecolor='y',linewidth=3)
plt.title("Histogram")
plt.xlabel("No Of Sales")
plt.ylabel("Years")
plt.show()

# %%
x=[86, 36, 40, 67, 21, 69, 23, 81, 31, 68, 92, 89, 86, 78, 70, 38, 72, 78, 46,
52, 26, 74, 99, 64, 90, 23, 86, 71, 93, 87, 35, 50, 93, 69, 76, 26, 30, 87,
62, 51, 37, 36, 98, 90, 22, 89, 28, 38, 85, 76, 85, 52, 28, 44, 56, 94, 95, 43, 91, 93]
l=[30,40,50,60,70,80,90]
plt.hist(x,color='m',bins=l,edgecolor='y',linewidth=3,bottom=10)
plt.title("Histogram")
plt.xlabel("No Of Sales")
plt.ylabel("Years")
plt.show()

# %%
x=[86, 36, 40, 67, 21, 69, 23, 81, 31, 68, 92, 89, 86, 78, 70, 38, 72, 78, 46,
52, 26, 74, 99, 64, 90, 23, 86, 71, 93, 87, 35, 50, 93, 69, 76, 26, 30, 87,
62, 51, 37, 36, 98, 90, 22, 89, 28, 38, 85, 76, 85, 52, 28, 44, 56, 94, 95, 43, 91, 93]
l=[30,40,50,60,70,80,90]
plt.hist(x,color='m',bins=l,edgecolor='y',linewidth=3,histtype="step")
plt.title("Histogram")
plt.xlabel("No Of Sales")
plt.ylabel("Years")
plt.show()

# %%
x=[86, 36, 40, 67, 21, 69, 23, 81, 31, 68, 92, 89, 86, 78, 70, 38, 72, 78, 46,
52, 26, 74, 99, 64, 90, 23, 86, 71, 93, 87, 35, 50, 93, 69, 76, 26, 30, 87,
62, 51, 37, 36, 98, 90, 22, 89, 28, 38, 85, 76, 85, 52, 28, 44, 56, 94, 95, 43, 91, 93]
l=[30,40,50,60,70,80,90]
plt.hist(x,color='m',bins=l,edgecolor='y',linewidth=3,orientation="horizontal")
plt.title("Histogram")
plt.xlabel("No Of Sales")
plt.ylabel("Years")
plt.show()

# %%
x=[86, 36, 40, 67, 21, 69, 23, 81, 31, 68, 92, 89, 86, 78, 70, 38, 72, 78, 46,
52, 26, 74, 99, 64, 90, 23, 86, 71, 93, 87, 35, 50, 93, 69, 76, 26, 30, 87,
62, 51, 37, 36, 98, 90, 22, 89, 28, 38, 85, 76, 85, 52, 28, 44, 56, 94, 95, 43, 91, 93]
l=[30,40,50,60,70,80,90]
plt.hist(x,color='m',bins=l,edgecolor='y',linewidth=3,rwidth=0.7,align="left")
plt.title("Histogram")
plt.xlabel("No Of Sales")
plt.ylabel("Years")
plt.show()

# %%
x=[86, 36, 40, 67, 21, 69, 23, 81, 31, 68, 92, 89, 86, 78, 70, 38, 72, 78, 46,
52, 26, 74, 99, 64, 90, 23, 86, 71, 93, 87, 35, 50, 93, 69, 76, 26, 30, 87,
62, 51, 37, 36, 98, 90, 22, 89, 28, 38, 85, 76, 85, 52, 28, 44, 56, 94, 95, 43, 91, 93]
l=[30,40,50,60,70,80,90]
plt.hist(x,color='m',bins=l,edgecolor='y',linewidth=3,label="Sales Report")
plt.title("Histogram")
plt.xlabel("No Of Sales")
plt.ylabel("Years")
plt.axvline(56,color="r",label="line")
plt.legend()
plt.show()
